# %%
from ib_insync import *
util.startLoop()

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=12)
# Out:
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 7497)")
# Make sure API port on TWS/IBG is open
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[14], line 5
#       2 util.startLoop()
#       4 ib = IB()
# ----> 5 ib.connect('127.0.0.1', 7497, clientId=12)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ib_insync/ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)
#     277         account: Main account to receive updates for.
# ...

# %%
ib = IB()
ib.connect('127.0.0.1',7497, clientId = 12)
# Out:
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 7497)")
# Make sure API port on TWS/IBG is open
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[12], line 2
#       1 ib = IB()
# ----> 2 ib.connect('127.0.0.1',7497, clientId = 12)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ib_insync/ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)
#     277         account: Main account to receive updates for.
#     278     """
# ...
